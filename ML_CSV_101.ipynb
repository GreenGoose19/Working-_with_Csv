# %% [markdown]
# <a href="https://colab.research.google.com/github/GreenGoose19/Working-_with_Csv/blob/main/ML_CSV_101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("tesla_stock.csv")
df.head()
# Out:
#          Date       Open       High       Low      Close  Adj Close    Volume
# 0  2014-01-02   9.986667  10.165333  9.770000  10.006667  10.006667  92826000
# 1  2014-01-03  10.000000  10.146000  9.906667   9.970667   9.970667  70425000
# 2  2014-01-06  10.000000  10.026667  9.682667   9.800000   9.800000  80416500
# 3  2014-01-07   9.841333  10.026667  9.683333   9.957333   9.957333  75511500
# 4  2014-01-08   9.923333  10.246667  9.917333  10.085333  10.085333  92448000

# %% [markdown]
# url

# %%
import requests
from io import StringIO

url = "https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}
req = requests.get(url, headers=headers)
data = StringIO(req.text)

pd.read_csv(data)
# Out:
#        Country         Region
# 0      Algeria         AFRICA
# 1       Angola         AFRICA
# 2        Benin         AFRICA
# 3     Botswana         AFRICA
# 4      Burkina         AFRICA
# ..         ...            ...
# 189   Paraguay  SOUTH AMERICA
# 190       Peru  SOUTH AMERICA
# 191   Suriname  SOUTH AMERICA
# 192    Uruguay  SOUTH AMERICA
# 193  Venezuela  SOUTH AMERICA
#
# [194 rows x 2 columns]

# %%
pd.read_csv("/content/movie_titles_metadata.tsv",sep='\t',names=['sno','names','year','imdb','length','genre'])
# Out:
#       sno                       names  year  imdb    length  \
# 0      m0  10 things i hate about you  1999   6.9   62847.0
# 1      m1  1492: conquest of paradise  1992   6.2   10421.0
# 2      m2                  15 minutes  2001   6.1   25854.0
# 3      m3       2001: a space odyssey  1968   8.4  163227.0
# 4      m4                     48 hrs.  1982   6.9   22289.0
# ..    ...                         ...   ...   ...       ...
# 612  m612                    watchmen  2009   7.8  135229.0
# 613  m613                         xxx  2002   5.6   53505.0
# 614  m614                       x-men  2000   7.4  122149.0
# 615  m615          young frankenstein  1974   8.0   57618.0
# 616  m616                   zulu dawn  1979   6.4    1911.0
#
#                                                  genre
# 0                                 ['comedy' 'romance']
# 1          ['adventure' 'biography' 'drama' 'history']
# 2                ['action' 'crime' 'drama' 'thriller']
# ...

# %%
df=pd.read_csv("/content/tesla_stock.csv",index_cols='Date')
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-01-02    9.986667   10.165333    9.770000   10.006667   10.006667
# 2014-01-03   10.000000   10.146000    9.906667    9.970667    9.970667
# 2014-01-06   10.000000   10.026667    9.682667    9.800000    9.800000
# 2014-01-07    9.841333   10.026667    9.683333    9.957333    9.957333
# 2014-01-08    9.923333   10.246667    9.917333   10.085333   10.085333
# ...                ...         ...         ...         ...         ...
# 2023-10-25  215.880005  220.100006  212.199997  212.419998  212.419998
# 2023-10-26  211.320007  214.800003  204.880005  205.759995  205.759995
# 2023-10-27  210.600006  212.410004  205.770004  207.300003  207.300003
# 2023-10-30  209.279999  210.880005  194.669998  197.360001  197.360001
# 2023-10-31  196.119995  202.800003  194.070007  200.839996  200.839996
#
#                Volume
# Date
# 2014-01-02   92826000
# 2014-01-03   70425000
# 2014-01-06   80416500
# ...

# %%
df=pd.read_csv("/content/tesla_stock.csv",usecols=['Date','Open'])
df
# Out:
#             Date        Open
# 0     2014-01-02    9.986667
# 1     2014-01-03   10.000000
# 2     2014-01-06   10.000000
# 3     2014-01-07    9.841333
# 4     2014-01-08    9.923333
# ...          ...         ...
# 2470  2023-10-25  215.880005
# 2471  2023-10-26  211.320007
# 2472  2023-10-27  210.600006
# 2473  2023-10-30  209.279999
# 2474  2023-10-31  196.119995
#
# [2475 rows x 2 columns]

# %%
df=pd.read_csv("/content/tesla_stock.csv",usecols=['Open'],squeeze=True)
df
# Out:
# <ipython-input-23-c024d08089c2>:1: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   df=pd.read_csv("/content/tesla_stock.csv",usecols=['Open'],squeeze=True)
# 0         9.986667
# 1        10.000000
# 2        10.000000
# 3         9.841333
# 4         9.923333
#            ...
# 2470    215.880005
# 2471    211.320007
# 2472    210.600006
# 2473    209.279999
# 2474    196.119995
# Name: Open, Length: 2475, dtype: float64

# %%
df=pd.read_csv("/content/tesla_stock.csv",chunksize=500)
for chunks in df:
  print(chunks.shape)
# Out:
# (500, 7)
# (500, 7)
# (500, 7)
# (500, 7)
# (475, 7)
